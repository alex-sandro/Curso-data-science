# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-sandro/Curso-data-science/blob/main/Curso_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Ler um arquivo CSV:

# %%
pd.read_csv("ratings.csv")
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# Armazenar o arquivo em uma variável e mostrar apenas as 5 primeiras notas:

# %%
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# Se eu quiser mostrar 10 notas?
# Passar o número como parâmetro para função head:

# %%
notas.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %% [markdown]
# Modificar o nome das colunas:

# %%
notas.columns = ["usuarioId", "filmesId", "nota", "momento"]

# %% [markdown]
# Exibir apenas a coluna de notas:

# %%
notas["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %% [markdown]
# Mostrar valores únicos:

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# Saber quantas vezes uma nota específica aparece nesta coluna:

# %%
notas["nota"].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %% [markdown]
# Calcular a média das notas:

# %%
notas["nota"].mean()
# Out:
# 3.501556983616962
